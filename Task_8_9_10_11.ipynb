# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Prepare data (Assuming df_run_dist_wkly is the weekly distance DataFrame column)
# Example: df_run_dist_wkly is a pandas Series with weekly running distances
df_run_dist_wkly = ...  # Add the actual DataFrame with weekly distance data

# Decompose the weekly trend
decomposed = sm.tsa.seasonal_decompose(df_run_dist_wkly, extrapolate_trend=1, period=52)

# Create plot
fig, ax = plt.subplots()

# Plot trend and observed data
ax = decomposed.trend.plot(label='Trend', linewidth=2, color='red', ax=ax)
decomposed.observed.plot(label='Observed', linewidth=0.5, ax=ax)

# Customize plot
ax.legend()
ax.set_title('Running Distance Trend')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import statsmodels.api as sm
#       2 import matplotlib.pyplot as plt
#       4 # Prepare data (Assuming df_run_dist_wkly is the weekly distance DataFrame column)
#       5 # Example: df_run_dist_wkly is a pandas Series with weekly running distances
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
import matplotlib.pyplot as plt

# Prepare data
hr_zones = [100, 125, 133, 142, 151, 173]
zone_names = ['Easy', 'Moderate', 'Hard', 'Very hard', 'Maximal']
zone_colors = ['green', 'yellow', 'orange', 'tomato', 'red']
df_run_hr_all = ...  # Add the actual heart rate data for each run

# Create plot
fig, ax = plt.subplots()

# Plot histogram and customize the color for each heart rate zone
n, bins, patches = ax.hist(df_run_hr_all, bins=hr_zones, alpha=0.5, edgecolor='black')
for i in range(len(patches)):
    patches[i].set_facecolor(zone_colors[i])

# Customize plot
ax.set(title='Distribution of Heart Rate Zones', ylabel='Number of Runs')
ax.xaxis.set(ticks=hr_zones)

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 13
#      10 fig, ax = plt.subplots()
#      12 # Plot histogram and customize the color for each heart rate zone
# ---> 13 n, bins, patches = ax.hist(df_run_hr_all, bins=hr_zones, alpha=0.5, edgecolor='black')
#      14 for i in range(len(patches)):
#      15     patches[i].set_facecolor(zone_colors[i])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
# ...

# %%
import pandas as pd

# Prepare data (assuming df_run_walk_cycle contains data for different types of activities like running, walking, and cycling)
df_run_walk_cycle = ...  # Add the actual DataFrame with 'Distance (km)', 'Climb (m)', and 'Average Speed (km/h)'

dist_climb_cols = ['Distance (km)', 'Climb (m)']
speed_col = ['Average Speed (km/h)']

# Calculating total distance and climb for each activity type
df_totals = df_run_walk_cycle.groupby('Type')[dist_climb_cols].sum()

print('Totals for different training types:')
display(df_totals)

# Calculating summary statistics
df_summary = df_run_walk_cycle.groupby('Type')[dist_climb_cols + speed_col].describe()

# Combine totals with summary statistics
for col in dist_climb_cols:
    df_summary[(col, 'total')] = df_totals[col]

print('Summary statistics for different training types:')
display(df_summary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       7 speed_col = ['Average Speed (km/h)']
#       9 # Calculating total distance and climb for each activity type
# ---> 10 df_totals = df_run_walk_cycle.groupby('Type')[dist_climb_cols].sum()
#      12 print('Totals for different training types:')
#      13 display(df_totals)
#
# AttributeError: 'ellipsis' object has no attribute 'groupby'

# %%
# Given values from the fun facts
total_km = 5224  # My total km
shoes_used = 7  # My shoes used
forrest_total_km = 24700  # Forrest's total km

# Calculate the average lifetime of shoes in km
average_shoes_lifetime = total_km / shoes_used

# Calculate the number of shoes Forrest needed
shoes_for_forrest_run = forrest_total_km / average_shoes_lifetime

print(f"Forrest Gump would need {int(shoes_for_forrest_run)} pairs of shoes!")
# Out:
# Forrest Gump would need 33 pairs of shoes!

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Prepare data (Assuming df_run_dist_wkly is the weekly distance DataFrame column)
# Example: df_run_dist_wkly is a pandas Series with weekly running distances
df_run_dist_wkly = ...  # Add the actual DataFrame with weekly distance data

# Decompose the weekly trend
decomposed = sm.tsa.seasonal_decompose(df_run_dist_wkly, extrapolate_trend=1, period=52)

# Create plot
fig, ax = plt.subplots()

# Plot trend and observed data
ax = decomposed.trend.plot(label='Trend', linewidth=2, color='red', ax=ax)
decomposed.observed.plot(label='Observed', linewidth=0.5, ax=ax)

# Customize plot
ax.legend()
ax.set_title('Running Distance Trend')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       6 df_run_dist_wkly = ...  # Add the actual DataFrame with weekly distance data
#       8 # Decompose the weekly trend
# ----> 9 decomposed = sm.tsa.seasonal_decompose(df_run_dist_wkly, extrapolate_trend=1, period=52)
#      11 # Create plot
#      12 fig, ax = plt.subplots()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\seasonal.py:150, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     147 if period is None:
#     148     pfreq = getattr(getattr(x, "index", None), "inferred_freq", None)
# --> 150 x = array_like(x, "x", maxdim=2)
#     151 nobs = len(x)
#     153 if not np.all(np.isfinite(x)):
#
# ...

# %%
import matplotlib.pyplot as plt

# Prepare data
hr_zones = [100, 125, 133, 142, 151, 173]
zone_names = ['Easy', 'Moderate', 'Hard', 'Very hard', 'Maximal']
zone_colors = ['green', 'yellow', 'orange', 'tomato', 'red']

# Example of heart rate data (replace with actual data)
df_run_hr_all = [120, 130, 145, 150, 110, 135, 140, 155, 125, 160]  # Replace with your actual data

# Create plot
fig, ax = plt.subplots()

# Plot histogram and customize the color for each heart rate zone
n, bins, patches = ax.hist(df_run_hr_all, bins=hr_zones, alpha=0.5, edgecolor='black')
for i in range(len(patches)):
    patches[i].set_facecolor(zone_colors[i])

# Customize plot
ax.set(title='Distribution of Heart Rate Zones', ylabel='Number of Runs')
ax.xaxis.set(ticks=hr_zones)

# Show plot
plt.show()

# %%
import pandas as pd

# Example of running, walking, and cycling data (replace with actual data)
data = {
    'Type': ['Run', 'Walk', 'Cycle', 'Run', 'Walk', 'Cycle'],
    'Distance (km)': [5.5, 3.2, 15.0, 10.3, 4.0, 20.1],
    'Climb (m)': [150, 50, 200, 180, 60, 250],
    'Average Speed (km/h)': [9.5, 5.0, 20.0, 10.2, 5.5, 22.1]
}
df_run_walk_cycle = pd.DataFrame(data)

dist_climb_cols = ['Distance (km)', 'Climb (m)']
speed_col = ['Average Speed (km/h)']

# Calculating total distance and climb for each activity type
df_totals = df_run_walk_cycle.groupby('Type')[dist_climb_cols].sum()

print('Totals for different training types:')
display(df_totals)

# Calculating summary statistics
df_summary = df_run_walk_cycle.groupby('Type')[dist_climb_cols + speed_col].describe()

# Combine totals with summary statistics
for col in dist_climb_cols:
    df_summary[(col, 'total')] = df_totals[col]

print('Summary statistics for different training types:')
display(df_summary)
# Out:
# Totals for different training types:
#        Distance (km)  Climb (m)
# Type
# Cycle           35.1        450
# Run             15.8        330
# Walk             7.2        110
# Summary statistics for different training types:
#       Distance (km)                                                      \
#               count   mean       std   min     25%    50%     75%   max
# Type
# Cycle           2.0  17.55  3.606245  15.0  16.275  17.55  18.825  20.1
# Run             2.0   7.90  3.394113   5.5   6.700   7.90   9.100  10.3
# Walk            2.0   3.60  0.565685   3.2   3.400   3.60   3.800   4.0
#
#       Climb (m)         ... Average Speed (km/h)                         \
#           count   mean  ...                count   mean       std   min
# Type                    ...
# Cycle       2.0  225.0  ...                  2.0  21.05  1.484924  20.0
# Run         2.0  165.0  ...                  2.0   9.85  0.494975   9.5
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd

# Prepare data (replace this with your actual weekly distance data)
# Example data: 52 weeks of running distances
data = {
    'Week': pd.date_range(start='2023-01-01', periods=52, freq='W'),
    'Distance': [5, 6, 7, 5, 6, 10, 12, 5, 6, 9, 7, 5, 11, 12, 9, 6, 8, 10, 5, 7, 6, 5, 9, 8, 11, 7,
                 10, 12, 5, 6, 8, 7, 9, 10, 5, 6, 12, 11, 6, 5, 7, 10, 9, 8, 7, 6, 5, 11, 9, 8, 12]
}
df = pd.DataFrame(data)
df.set_index('Week', inplace=True)

# The series containing weekly distances
df_run_dist_wkly = df['Distance']

# Decompose the weekly trend (set period to 52 weeks)
decomposed = sm.tsa.seasonal_decompose(df_run_dist_wkly, extrapolate_trend=1, period=52)

# Create plot
fig, ax = plt.subplots()

# Plot trend and observed data
decomposed.trend.plot(label='Trend', linewidth=2, color='red', ax=ax)
decomposed.observed.plot(label='Observed', linewidth=0.5, ax=ax)

# Customize plot
ax.legend()
ax.set_title('Running Distance Trend')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 12
#       5 # Prepare data (replace this with your actual weekly distance data)
#       6 # Example data: 52 weeks of running distances
#       7 data = {
#       8     'Week': pd.date_range(start='2023-01-01', periods=52, freq='W'),
#       9     'Distance': [5, 6, 7, 5, 6, 10, 12, 5, 6, 9, 7, 5, 11, 12, 9, 6, 8, 10, 5, 7, 6, 5, 9, 8, 11, 7,
#      10                  10, 12, 5, 6, 8, 7, 9, 10, 5, 6, 12, 11, 6, 5, 7, 10, 9, 8, 7, 6, 5, 11, 9, 8, 12]
#      11 }
# ---> 12 df = pd.DataFrame(data)
#      13 df.set_index('Week', inplace=True)
#      15 # The series containing weekly distances
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd

# Prepare data (replace this with your actual weekly distance data)
# Example data: 52 weeks of running distances
data = {
    'Week': pd.date_range(start='2023-01-01', periods=52, freq='W'),
    'Distance': [5, 6, 7, 5, 6, 10, 12, 5, 6, 9, 7, 5, 11, 12, 9, 6, 8, 10, 5, 7, 6, 5, 9, 8, 11, 7,
                 10, 12, 5, 6, 8, 7, 9, 10, 5, 6, 12, 11, 6, 5, 7, 10, 9, 8, 7, 6, 5, 11, 9, 8, 12]  # 52 values
}

# Check if the lengths of 'Week' and 'Distance' match
print(len(data['Week']), len(data['Distance']))  # Should both print 52

# Create DataFrame
df = pd.DataFrame(data)
df.set_index('Week', inplace=True)

# The series containing weekly distances
df_run_dist_wkly = df['Distance']

# Decompose the weekly trend (set period to 52 weeks)
decomposed = sm.tsa.seasonal_decompose(df_run_dist_wkly, extrapolate_trend=1, period=52)

# Create plot
fig, ax = plt.subplots()

# Plot trend and observed data
decomposed.trend.plot(label='Trend', linewidth=2, color='red', ax=ax)
decomposed.observed.plot(label='Observed', linewidth=0.5, ax=ax)

# Customize plot
ax.legend()
ax.set_title('Running Distance Trend')
plt.show()
# Out:
# 52 51
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 17
#      14 print(len(data['Week']), len(data['Distance']))  # Should both print 52
#      16 # Create DataFrame
# ---> 17 df = pd.DataFrame(data)
#      18 df.set_index('Week', inplace=True)
#      20 # The series containing weekly distances
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd

# Prepare data (replace this with your actual weekly distance data)
# Example data: 52 weeks of running distances
data = {
    'Week': pd.date_range(start='2023-01-01', periods=52, freq='W'),
    'Distance': [5, 6, 7, 5, 6, 10, 12, 5, 6, 9, 7, 5, 11, 12, 9, 6, 8, 10, 5, 7, 6, 5, 9, 8, 11, 7,
                 10, 12, 5, 6, 8, 7, 9, 10, 5, 6, 12, 11, 6, 5, 7, 10, 9, 8, 7, 6, 5, 11, 9, 8, 12]  # 52 values
}

# Check if the lengths of 'Week' and 'Distance' match
print(len(data['Week']), len(data['Distance']))  # Should both print 52

# Create DataFrame
df = pd.DataFrame(data)
df.set_index('Week', inplace=True)

# The series containing weekly distances
df_run_dist_wkly = df['Distance']

# Decompose the weekly trend (set period to 52 weeks)
decomposed = sm.tsa.seasonal_decompose(df_run_dist_wkly, extrapolate_trend=1, period=52)

# Create plot
fig, ax = plt.subplots()

# Plot trend and observed data
decomposed.trend.plot(label='Trend', linewidth=2, color='red', ax=ax)
decomposed.observed.plot(label='Observed', linewidth=0.5, ax=ax)

# Customize plot
ax.legend()
ax.set_title('Running Distance Trend')
plt.show()
# Out:
# 52 51
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 17
#      14 print(len(data['Week']), len(data['Distance']))  # Should both print 52
#      16 # Create DataFrame
# ---> 17 df = pd.DataFrame(data)
#      18 df.set_index('Week', inplace=True)
#      20 # The series containing weekly distances
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd

# Prepare data (replace this with your actual weekly distance data)
# Example data: 52 weeks of running distances
data = {
    'Week': pd.date_range(start='2023-01-01', periods=52, freq='W'),
    'Distance': [5, 6, 7, 5, 6, 10, 12, 5, 6, 9, 7, 5, 11, 12, 9, 6, 8, 10, 5, 7, 6, 5, 9, 8, 11, 7,
                 10, 12, 5, 6, 8, 7, 9, 10, 5, 6, 12, 11, 6, 5, 7, 10, 9, 8, 7, 6, 5, 11, 9, 8, 12]  # 52 values
}

# Check if the lengths of 'Week' and 'Distance' match
print(len(data['Week']), len(data['Distance']))  # Should both print 52

# Create DataFrame
df = pd.DataFrame(data)
df.set_index('Week', inplace=True)

# The series containing weekly distances
df_run_dist_wkly = df['Distance']

# Decompose the weekly trend (set period to 52 weeks)
decomposed = sm.tsa.seasonal_decompose(df_run_dist_wkly, extrapolate_trend=1, period=52)

# Create plot
fig, ax = plt.subplots()

# Plot trend and observed data
decomposed.trend.plot(label='Trend', linewidth=2, color='red', ax=ax)
decomposed.observed.plot(label='Observed', linewidth=0.5, ax=ax)

# Customize plot
ax.legend()
ax.set_title('Running Distance Trend')
plt.show()
# Out:
# 52 51
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 17
#      14 print(len(data['Week']), len(data['Distance']))  # Should both print 52
#      16 # Create DataFrame
# ---> 17 df = pd.DataFrame(data)
#      18 df.set_index('Week', inplace=True)
#      20 # The series containing weekly distances
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd

# Prepare data (replace this with your actual weekly distance data)
# Example data: 52 weeks of running distances
data = {
    'Week': pd.date_range(start='2023-01-01', periods=52, freq='W'),
    'Distance': [5, 6, 7, 5, 6, 10, 12, 5, 6, 9, 7, 5, 11, 12, 9, 6, 8, 10, 5, 7, 6, 5, 9, 8, 11, 7,
                 10, 12, 5, 6, 8, 7, 9, 10, 5, 6, 12, 11, 6, 5, 7, 10, 9, 8, 7, 6, 5, 11, 9, 8, 12]  # 52 values
}

# Check if the lengths of 'Week' and 'Distance' match
print(len(data['Week']), len(data['Distance']))  # Should both print 52

# Ensure data types are correct
print(type(data['Week']), type(data['Distance']))  # Should print <class 'pandas.core.indexes.datetimes.DatetimeIndex'> <class 'list'>

# Create DataFrame
df = pd.DataFrame(data)
df.set_index('Week', inplace=True)

# The series containing weekly distances
df_run_dist_wkly = df['Distance']

# Decompose the weekly trend (set period to 52 weeks)
decomposed = sm.tsa.seasonal_decompose(df_run_dist_wkly, extrapolate_trend=1, period=52)

# Create plot
fig, ax = plt.subplots()

# Plot trend and observed data
decomposed.trend.plot(label='Trend', linewidth=2, color='red', ax=ax)
decomposed.observed.plot(label='Observed', linewidth=0.5, ax=ax)

# Customize plot
ax.legend()
ax.set_title('Running Distance Trend')
plt.show()
# Out:
# 52 51
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'> <class 'list'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 20
#      17 print(type(data['Week']), type(data['Distance']))  # Should print <class 'pandas.core.indexes.datetimes.DatetimeIndex'> <class 'list'>
#      19 # Create DataFrame
# ---> 20 df = pd.DataFrame(data)
#      21 df.set_index('Week', inplace=True)
#      23 # The series containing weekly distances
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# ...
